# %% [markdown]
# <a href="https://colab.research.google.com/github/Pravallikavyas/User-engagement/blob/main/task5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# The data is about the users who login to buy a product or browse the product about its details.
# Here all the data is in numerical format.Some of the categorical data is converted into numerical by encoding like fields like visited.We are provided with the data which contains at which date,which user and at what time the user has visited the page.We have the data of user name,mailid,account creation source,account creation time,time where the user was previously login.
# Here some users are opted to mailing list to get frequent mails about products and others are enabled for marketing drip.
# There are also some users who are invited by other users.
# Our objective is to predict the factors for future user adoption.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
dataset=pd.read_csv("/content/drive/MyDrive/Copy of takehome_users.csv",encoding="latin-1")

# %%
dataset
# Out:
#        object_id        creation_time               name  \
# 0              1  2014-04-22 03:53:30     Clausen August
# 1              2  2013-11-15 03:45:04      Poole Matthew
# 2              3  2013-03-19 23:14:52  Bottrill Mitchell
# 3              4  2013-05-21 08:09:28    Clausen Nicklas
# 4              5  2013-01-17 10:14:20          Raw Grace
# ...          ...                  ...                ...
# 11995      11996  2013-09-06 06:14:15       Meier Sophia
# 11996      11997  2013-01-10 18:28:37      Fisher Amelie
# 11997      11998  2014-04-27 12:45:16        Haynes Jake
# 11998      11999  2012-05-31 11:55:59       Faber Annett
# 11999      12000  2014-01-26 08:57:12         Lima Thaís
#
#                             email     creation_source  \
# 0        AugustCClausen@yahoo.com        GUEST_INVITE
# 1          MatthewPoole@gustr.com          ORG_INVITE
# 2      MitchellBottrill@gustr.com          ORG_INVITE
# 3       NicklasSClausen@yahoo.com        GUEST_INVITE
# ...

# %%
dataset.head()
# Out:
#    object_id        creation_time               name  \
# 0          1  2014-04-22 03:53:30     Clausen August
# 1          2  2013-11-15 03:45:04      Poole Matthew
# 2          3  2013-03-19 23:14:52  Bottrill Mitchell
# 3          4  2013-05-21 08:09:28    Clausen Nicklas
# 4          5  2013-01-17 10:14:20          Raw Grace
#
#                         email creation_source  last_session_creation_time  \
# 0    AugustCClausen@yahoo.com    GUEST_INVITE                1.398139e+09
# 1      MatthewPoole@gustr.com      ORG_INVITE                1.396238e+09
# 2  MitchellBottrill@gustr.com      ORG_INVITE                1.363735e+09
# 3   NicklasSClausen@yahoo.com    GUEST_INVITE                1.369210e+09
# 4          GraceRaw@yahoo.com    GUEST_INVITE                1.358850e+09
#
#    opted_in_to_mailing_list  enabled_for_marketing_drip  org_id  \
# 0                         1                           0      11
# 1                         0                           0       1
# ...

# %%
dataset.info( )
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12000 entries, 0 to 11999
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   object_id                   12000 non-null  int64
#  1   creation_time               12000 non-null  object
#  2   name                        12000 non-null  object
#  3   email                       12000 non-null  object
#  4   creation_source             12000 non-null  object
#  5   last_session_creation_time  8823 non-null   float64
#  6   opted_in_to_mailing_list    12000 non-null  int64
#  7   enabled_for_marketing_drip  12000 non-null  int64
#  8   org_id                      12000 non-null  int64
#  9   invited_by_user_id          6417 non-null   float64
# dtypes: float64(2), int64(4), object(4)
# memory usage: 937.6+ KB

# %%
dataset.describe( )
# Out:
#          object_id  last_session_creation_time  opted_in_to_mailing_list  \
# count  12000.00000                8.823000e+03              12000.000000
# mean    6000.50000                1.379279e+09                  0.249500
# std     3464.24595                1.953116e+07                  0.432742
# min        1.00000                1.338452e+09                  0.000000
# 25%     3000.75000                1.363195e+09                  0.000000
# 50%     6000.50000                1.382888e+09                  0.000000
# 75%     9000.25000                1.398443e+09                  0.000000
# max    12000.00000                1.402067e+09                  1.000000
#
#        enabled_for_marketing_drip        org_id  invited_by_user_id
# count                12000.000000  12000.000000         6417.000000
# mean                     0.149333    141.884583         5962.957145
# std                      0.356432    124.056723         3383.761968
# ...

# %%
data=pd.read_csv("/content/drive/MyDrive/Copy of takehome_user_engagement.csv",encoding='Latin-1',parse_dates=True)

# %%
data
# Out:
#                  time_stamp  user_id  visited
# 0       2014-04-22 03:53:30        1        1
# 1       2013-11-15 03:45:04        2        1
# 2       2013-11-29 03:45:04        2        1
# 3       2013-12-09 03:45:04        2        1
# 4       2013-12-25 03:45:04        2        1
# ...                     ...      ...      ...
# 207912  2013-09-06 06:14:15    11996        1
# 207913  2013-01-15 18:28:37    11997        1
# 207914  2014-04-27 12:45:16    11998        1
# 207915  2012-06-02 11:55:59    11999        1
# 207916  2014-01-26 08:57:12    12000        1
#
# [207917 rows x 3 columns]

# %%
data.shape
# Out:
# (207917, 3)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 207917 entries, 0 to 207916
# Data columns (total 3 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   time_stamp  207917 non-null  object
#  1   user_id     207917 non-null  int64
#  2   visited     207917 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 4.8+ MB

# %%
data.describe( )
# Out:
#              user_id   visited
# count  207917.000000  207917.0
# mean     5913.314197       1.0
# std      3394.941674       0.0
# min         1.000000       1.0
# 25%      3087.000000       1.0
# 50%      5682.000000       1.0
# 75%      8944.000000       1.0
# max     12000.000000       1.0

# %%
df=pd.DataFrame(data['visited'])
df
v=df.to_numpy( )

# %%
data=data.set_index(pd.DatetimeIndex(data['time_stamp']))

# %%
#groups by user, then date by week, and sums number of visits per week
user_id = pd.DataFrame(data.groupby('user_id').resample('1W').sum())
#removes weeks that were imputed for grouping but are NaN
user_id = user_id[user_id['user_id'].isnull()==False].drop('user_id',axis=1)
user_id.head( )
# Out:
#                     visited
# user_id time_stamp
# 1       2014-04-27        1
# 2       2013-11-17        1
#         2013-11-24        0
#         2013-12-01        1
#         2013-12-08        0

# %%
user_id
# Out:
#                     visited
# user_id time_stamp
# 1       2014-04-27        1
# 2       2013-11-17        1
#         2013-11-24        0
#         2013-12-01        1
#         2013-12-08        0
# ...                     ...
# 11996   2013-09-08        1
# 11997   2013-01-20        1
# 11998   2014-04-27        1
# 11999   2012-06-03        1
# 12000   2014-01-26        1
#
# [82282 rows x 1 columns]

# %%
user_id.isnull( ).sum()
# Out:
# visited    0
# dtype: int64
